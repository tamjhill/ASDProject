# %%
#Rosalind problem #6

dataset = "..."
print(dataset.count("A"), dataset.count("C"), dataset.count("G"), dataset.count("T"))
# Out:
# 201 202 263 182

# %%
#Rosalind problem #7 v1

data2 = "..."
print(data2.replace("T","U"))
# Out:
# ...

# %%
#Rosalind problem #7 v2

from Bio.Seq import Seq

data2 = Seq("...")
rna_data2 = data2.transcribe()
rna_data2
# Out:
# Seq('CUCACCAUACUGAUACACGCGCUGAUGGCUUAUUCUGCGUAUGAUAAAUUAAAA...CAC')

# %%
#Rosalind problem #8

from Bio.Seq import Seq

data3 = Seq("...")
comp_data3 = data3.reverse_complement()
print(comp_data3)
# Out:
# ...

# %%
#Rosalind problem #9
